# %%
import numpy
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
year = [2012,2013,2014,2015,2016,2017]
salary = [12,13,14,17,19,20]
population = [100,120,180,250,300,370]
plt.bar(year,salary)
# Out:
# <BarContainer object of 6 artists>

# %%
# Changing width of the bar graph
plt.bar(year,salary,0.2)
# Out:
# <BarContainer object of 6 artists>

# %%
# Avoiding overlapping in any graph using plt.xticks(rotation=angle)
year = ["year = 2012","year = 2013","year = 2014","year = 2015","year = 2016","year = 2017"]
salary = [12,13,14,17,19,20]
population = [100,120,180,250,300,370]
plt.xticks(rotation=40)
plt.bar(year, salary,0.5)
# Out:
# <BarContainer object of 6 artists>
